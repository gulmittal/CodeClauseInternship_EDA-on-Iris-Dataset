# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
iris = datasets.load_iris()

# %%
df=pd.DataFrame(data=iris.data, columns=iris.feature_names)

# %%
y= pd.DataFrame(data=iris.target, columns=['Species'])

# %%
y.head()
# Out:
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
y.value_counts()
# Out:
# Species
# 0          50
# 1          50
# 2          50
# Name: count, dtype: int64

# %%
plt.hist(y,color='#BDE2B9')
plt.title('Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df.shape
# Out:
# (150, 4)

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
(df.isnull().sum() / df.shape[0]*100).sort_values(ascending=False)
# Out:
# sepal length (cm)    0.0
# sepal width (cm)     0.0
# petal length (cm)    0.0
# petal width (cm)     0.0
# dtype: float64

# %%
df.nunique()
# Out:
# sepal length (cm)    35
# sepal width (cm)     23
# petal length (cm)    43
# petal width (cm)     22
# dtype: int64

# %%
y1=pd.DataFrame(data=iris.target_names, columns=['Species'])

# %%
y1
# Out:
#       Species
# 0      setosa
# 1  versicolor
# 2   virginica

# %%
df.hist(figsize=(15,5),grid=False)
plt.show()

# %%
for feature in iris.feature_names:
  sns.displot(df[feature], kde=True, color='green')
  plt.show()

# %%
sns.set_style('darkgrid')
sns.set_palette('pastel')
sns.heatmap(df.corr(),cmap='Greens',annot=True)
# Out:
# <Axes: >

# %%
for feature in iris.feature_names:
  df.groupby(y)[feature].mean().plot(kind='bar',color='orange')
  plt.xlabel('Species')
  plt.ylabel("Mean " + feature)
  plt.title("Mean " + feature + " by Species")
  plt.show()

# %%
for feature in iris.feature_names:
    sns.boxplot(x=df[feature])
    plt.show()

# %%
sns.set(style="ticks")
sns.pairplot(df, plot_kws={'color':'blue'})
plt.show()
